# %%
import numpy as np
import gymnasium as gym
from mdps import MDP, RiverSwimMDP, SixArmsMDP
from mbie import MBIE, runs
from value_iteration import q_value_iteration_w_ci
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
MAX_REWARD = 6_000
A = 0.3
B = 0.08
GAMMA = 0.95
env = SixArmsMDP()
array = np.array(runs(env, MAX_REWARD, GAMMA, A, B, 10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 GAMMA = 0.95
#       5 env = SixArmsMDP()
# ----> 6 array = np.array(runs(env, MAX_REWARD, GAMMA, A, B, 10))
#
# NameError: name 'runs' is not defined
